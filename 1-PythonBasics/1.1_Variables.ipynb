# %% [markdown]
# ### Variables in Python

# %%
j=10
k=20
i=30
l=(i+j+k)*9000
print(l)
# Out:
# 540000

# %%
print("Krishna I guess")
# Out:
# Krishna I guess

# %%
## Declaring and Assigning variables
a=100
age=27
height=6.0
print(type(a))
name="Saurabh Ganguly"
is_student=True
print("age:",age)
print("Name:",name)
print("Height",height)
# Out:
# <class 'int'>
# age: 27
# Name: Saurabh Ganguly
# Height 6.0

# %%
## Naming conventions
## variables name should be descriptive.
## They must start with letter or underscore '_' and contains letter,numbers and undersores.
## variables names case sensitive

# valid variable name.
first_name="Rushikesh"
Last_name="More"

# %%
# invslid variable names
#age=20;
#first-name="rushi"
##@name="lion"
# Out:
#   Cell In[8], line 4
#     @name="lion"
#      ^
# SyntaxError: invalid syntax. Maybe you meant '==' or ':=' instead of '='?

# %%
## understanding variable types
## python is dynamic typed,type of variable is determined at runtime.
age=25 #int
height=6.1 #float
name="Rushikesh"#str
is_student=True #bool
print(type(height))
# Out:
# <class 'float'>

# %%
age=26
print(type(age))
#type conversion 
age_str=str(age)
print(age_str)
print(type(age_str))
# Out:
# <class 'int'>
# 26
# <class 'str'>

# %%
age='26'
print(type(int(age)))
# Out:
# <class 'int'>

# %%
height=5.11
type(height)
# Out:
# float

# %%
int(height)
print(height)
print(type(height))
# Out:
# 5.11
# <class 'float'>

# %%
name="Rushi"
int(name)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 2
#       1 name="Rushi"
# ----> 2 int(name)
#
# ValueError: invalid literal for int() with base 10: 'Rushi'

# %%
## Dybnamic typing
## Python allows the type of variable to change as the program executes
var=10
print(var,type(var))
var="hello"
print(var,type(var))
var=3.14
print(var,type(var))
# Out:
# 10 <class 'int'>
# hello <class 'str'>
# 3.14 <class 'float'>

# %%
## input
age=int(input("what is the age"))
print(age,type(age))
# Out:
# 1025 <class 'int'>

# %%
num1=float(input("Enter First Number:"))
num2=float(input("Enter second number:"))
sum=num1+num2
diff=num1-num2
product=num1*num2
quotient=num1/num2

print("sum:",sum)
print("difference:",diff)
print("Product:",product)
print("Quotient:",quotient)
# Out:
# sum: 101.0
# difference: 11.0
# Product: 2520.0
# Quotient: 1.2444444444444445
