# %%
1+1
# Out:
# 2

# %% [markdown]
# ### Python Example

# %%
print("Rushikesh More")
# Out:
# Rushikesh More

# %%
print("Python Basics")
# Out:
# Python Basics

# %%
## Basic Syntax rule in Python
## Case Sensitivity-Python is case sensitive
name="Rushikesh";
Name="More";
print(name,Name)
# Out:
# Rushikesh More

# %%
## Indentation
## Python uses indentation to define blocks of code,consistent use of spaces(commonly 4) or tab is required.

age=32
if age>30:
    print("age is greater than 30",age)
else:
    print("age is less than 30",age)
# Out:
# age is greater than 30 32

# %%
## This is Single line comment
print("Hello world!")
# Out:
# Hello world!

# %%
## line continuation
total=1+2+3+4+5+6+\
7+8+9
print(total)
# Out:
# 45

# %%
## Multiple statements on a single line.
x=10;
y=20;z=x*y;
print(z);
# Out:
# 200

# %%
## Understand semantics in python
# variable assignment
age=322 ##age is an integer
name="krish" ## name is string

# %%
type(age)
type(name)
# Out:
# str

# %%
## type inference it is basically changing the variable type at runtime by assigning the different values
variable=10
print(type(variable))
variable="krish"
print(type(variable))
# Out:
# <class 'int'>
# <class 'str'>

# %%
## name error
a=b
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 2
#       1 ## name error
# ----> 2 a=b
#
# NameError: name 'b' is not defined

# %%
## code examples for indentation
if True:
    print("correct identation")
    if False:
        print("this not prints")
    print("this will print")
print("outside if block")
# Out:
# correct identation
# this will print
# outside if block

# %%
x=30;y=20;
if x==y:
    print("x is equal to y")
else:
    print("x is not equal to y")
# Out:
# x is not equal to y

# %%
print("Web Developer and AI enthusiast")
# Out:
# Web Developer and AI enthusiast

# %%
print("Assistant professor")
# Out:
# Assistant professor
