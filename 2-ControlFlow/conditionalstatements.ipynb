# %% [markdown]
# ## Conditional Statements
# ### 1.if
# ### 2.if else
# ### 3.elif
# ### 4.Nested If else

# %%
## if statements
age=20
if age>=18:
    print("You are allowed to vote in the elections")
# Out:
# You are allowed to vote in the elections

# %%
## else
## The else statements executes a block of code if the condition in the if statement is false
age=16
if age>=18:
    print("You are eligible for voting")
else:
    print("You are a minor")
# Out:
# You are a minor

# %%
## elif
## The elif statement allows you to check for multiple conditions.It stands for "else if".

age=17
if age<13:
    print("You are a child")
elif age<18:
    print("You are a teenager")
else:
    print("You are an adult")
# Out:
# You are a teenager

# %%
## Nested conditional Statements
## You can place one or more if,elif or else statemensts inside another if,elif,or else statement to nested conditional statements.
## number even,odd,negative
num=int(input("Enter the number"))
if num>0:
    print("Number is positive",num)
    if num%2==0:
        print("Number is even" ,num)
    else:
        print("number is odd" ,num)
else:
    print("The number is zero or negative")
# Out:
# Number is positive 52
# Number is even 52

# %%
## Practical examples

## Determine if a year is a leap year using nested condition statement
year=int(input("Enter the Year"))
if year%4==0:
    if year%100==0:
        if year%400==0:
             print(year ,"is leap year ")
        else:
            print(year ,"is not leap year") 
    else:
        print(year,"is leap year")
else:
    print(year,"is not a leap year")
# Out:
# 2024 is leap year

# %%
## Assignmenst
## simple calculator Program

num1=int(input("Enter the first number"))
num2=int(input("Enter the second number"))
operation=input("Enter the operation(+,-,*,/):")

if operation=="+":
    result=num1+num2
elif operation=="-":
    result=num1-num2
elif operation=="*":
    result=num1*num2
elif operation=="/":
    if num2!=0:
        result=num1/num2
    else:
        result="Division by zero error"

else:
    result="Invalid Operation."

print("First Number is",num1)
print("second Number is",num2)
print("Result is",result)
# Out:
# First Number is 25
# second Number is 30
# Result is -5
